# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams["figure.figsize"]=(10,6) #butun gorsellerin notebookta ayni boyutta olmasini saglar

import warnings
warnings.filterwarnings("ignore") #verilen uyarilarin goz ardi edilmesi icin

# %% [markdown]
# ## Read Dataset

# %%
df = pd.read_csv("Advertising (1).csv", encoding="utf-8")

# %% [markdown]
# ![image.png](attachment:d3abaaa4-696d-4a5a-902f-707094bd9f21.png)![image.png](attachment:20b24eef-9597-451b-a1a8-8eba3ae9ef02.png)

# %%
df.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df.sample(5)
# Out:
#         TV  radio  newspaper  sales
# 187  191.1   28.7       18.2   17.3
# 29    70.6   16.0       40.8   10.5
# 53   182.6   46.2       58.7   21.2
# 64   131.1   42.8       28.9   18.0
# 117   76.4    0.8       14.8    9.4

# %%
df.tail()
# Out:
#         TV  radio  newspaper  sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.describe().T
# Out:
#            count      mean        std  min     25%     50%      75%    max
# TV         200.0  147.0425  85.854236  0.7  74.375  149.75  218.825  296.4
# radio      200.0   23.2640  14.846809  0.0   9.975   22.90   36.525   49.6
# newspaper  200.0   30.5540  21.778621  0.3  12.750   25.75   45.100  114.0
# sales      200.0   14.0225   5.217457  1.6  10.375   12.90   17.400   27.0

# %%
df.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
#diagonal cizginin altinda ve ustunde kalan degerler dogal olarak aynidir.
#sales ile TV arasindaki yuksek korelasyon aralarinda yuksek iliski oldugunu gosterir.

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# features= TV, sales, newspaper
# target= sales

# %% [markdown]
# ![image.png](attachment:6f0ac385-904b-4cb2-a3bf-8c0b019296cb.png)![image.png](attachment:87b7cbce-a4b6-41e9-a901-d64b11db3787.png)

# %%
df.total

# %%
# !pip install scipy
import scipy.stats as stats

# %%
for i in df.drop(columns = "sales"):
    print(f"corr between sales and {i:<15}: {df.sales.corr(df[i])}")
# Out:
# corr between sales and TV             : 0.7822244248616061
# corr between sales and radio          : 0.5762225745710551
# corr between sales and newspaper      : 0.22829902637616528

# %% [markdown]
# ## yeni data frame ile devam ediyoruz
